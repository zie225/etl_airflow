# %%
# !pip install psycopg2
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 1.2/1.2 MB 3.0 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
from time import time
from sqlalchemy import create_engine
import psycopg2
import random
import uuid
import pandas as pd
import mysql.connector
from datetime import datetime, timedelta
import mysql.connector
from mysql.connector.constants import ClientFlag
import geopandas as gpd
import pandas
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
import sqlite3
pg_user="airflow"
pg_password="airflow"
pg_host="localhost"
pg_port="5432"
pg_db="poll_data"
#pg_table=
csv_path="data.csv"

# %%
df=pd.read_csv('data2.csv',sep=';')

# %%
df
# Out:
#        code_insee  val_ind  conc_pm10  conc_pm25  conc_no2  conc_so2  conc_o3  \
# 0           28415        4       22.7       11.6      23.8       0.4    155.7
# 1           37094        4       16.2        9.4      16.1       0.1    145.1
# 2           18273        4       12.6        7.5      12.9       0.2    137.6
# 3           41217        4       14.5        8.3      16.7       0.1    149.0
# 4           28182        4       20.4       10.4      21.9       0.2    152.3
# ...           ...      ...        ...        ...       ...       ...      ...
# 15808       28296        4       19.1        9.7      19.8       0.2    150.2
# 15809       41286        4       16.4        8.8      19.1       0.1    150.8
# 15810       37169        4       16.1        8.8      19.3       0.1    149.8
# 15811       18226        4       14.8        8.0      16.1       0.2    135.9
# 15812       18179        4       14.4        7.7      15.1       0.1    136.8
#
# ...

# %%
engine = create_engine(f"postgresql://{pg_user}:{pg_password}@{pg_host}:{pg_port}/{pg_db}")
con = engine.connect()

# %%
#conn = psycopg2.connect(database = pg_db,
                        #user = pg_user, 
                       # host= 'localhost',
                        #password = pg_password,
                        #port = 5432)

# %%
df=pd.read_csv('data2.csv',sep=';')
#df = next(df_iter)

#df.date_run = pd.to_datetime(df.date_run)
#df.date_ech = pd.to_datetime(df.date_ech)



#df.head(0).to_sql(con=con, name="pollution_data", if_exists="replace")

df.to_sql(con=con, name="pollution_data", if_exists="replace")
# Out:
# 813

# %%
df=pd.read_csv('data2.csv',sep=';')
#df = next(df_iter)

#df.date_run = pd.to_datetime(df.date_run)
#df.date_ech = pd.to_datetime(df.date_ech)



df.head(0).to_sql(con=con, name="pollution_data", if_exists="replace")

df.to_sql(con=con, name="pollution_data", if_exists="replace")
"""
try:
    
    while True:
        t_start = time()
        df = df
  
        df.date_run = pd.to_datetime(df.date_run)
        df.date_ech = pd.to_datetime(df.date_ech)
        df.to_sql(con=con, name=pg_db, if_exists="replace")
  
        end_time = time()
        print("New records added {}".format(end_time-t_start))
except StopIteration:
    print("All records ingested")
    
    """
# Out:
# C:\Users\ZIE MAMADOU\AppData\Roaming\Python\Python39\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14/06/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ZIE MAMADOU\AppData\Roaming\Python\Python39\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15/06/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ZIE MAMADOU\AppData\Roaming\Python\Python39\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16/06/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# ...

# %%
from datetime import date, datetime

datetime.now().strftime("%d/%m/%Y %H:%M:%S")
# Out:
# '15/08/2023 08:51:38'

# %%
# connect to db
engine = create_engine("postgresql://airflow:airflow@localhost:5432/poll_data").connect()
engine

# %%
#df=pd.read_sql("SELECT * FROM pollution_data",engine)

# %%
print(pd.io.sql.get_schema(df, name="pollution_data", con=engine))
# Out:
# CREATE TABLE pollution_data (
# 	code_insee BIGINT,
# 	val_ind BIGINT,
# 	conc_pm10 FLOAT(53),
# 	conc_pm25 FLOAT(53),
# 	conc_no2 FLOAT(53),
# 	conc_so2 FLOAT(53),
# 	conc_o3 FLOAT(53),
# 	poll_resp TEXT,
# 	date_run TIMESTAMP WITHOUT TIME ZONE,
# 	date_ech TIMESTAMP WITHOUT TIME ZONE
# )

# %%
gdf = gpd.read_file("georef-france-commune-millesime.shp")

# %%
gdf
# Out:
#       year reg_code             reg_name dep_code      dep_name arrdep_code  \
# 0     2021       24  Centre-Val de Loire       18          Cher         182
# 1     2021       24  Centre-Val de Loire       18          Cher         182
# 2     2021       24  Centre-Val de Loire       18          Cher         181
# 3     2021       24  Centre-Val de Loire       18          Cher         182
# 4     2021       24  Centre-Val de Loire       18          Cher         181
# ...    ...      ...                  ...      ...           ...         ...
# 1752  2021       24  Centre-Val de Loire       28  Eure-et-Loir         282
# 1753  2021       24  Centre-Val de Loire       28  Eure-et-Loir         283
# 1754  2021       24  Centre-Val de Loire       28  Eure-et-Loir         283
# 1755  2021       24  Centre-Val de Loire       28  Eure-et-Loir         281
# 1756  2021       24  Centre-Val de Loire       28  Eure-et-Loir         282
#
# ...

# %%
gdf = gdf.to_csv("georef.csv")
print(gdf)
# Out:
# None

# %%
gdf = pd.read_csv("georef.csv")
print(gdf.drop('Unnamed: 0', axis=1, inplace=True))
print(gdf.dropna(axis=1, inplace=True))
# Out:
# None
# None

# %%
gdf
# Out:
#       year  reg_code             reg_name  dep_code      dep_name  \
# 0     2021        24  Centre-Val de Loire        18          Cher
# 1     2021        24  Centre-Val de Loire        18          Cher
# 2     2021        24  Centre-Val de Loire        18          Cher
# 3     2021        24  Centre-Val de Loire        18          Cher
# 4     2021        24  Centre-Val de Loire        18          Cher
# ...    ...       ...                  ...       ...           ...
# 1752  2021        24  Centre-Val de Loire        28  Eure-et-Loir
# 1753  2021        24  Centre-Val de Loire        28  Eure-et-Loir
# 1754  2021        24  Centre-Val de Loire        28  Eure-et-Loir
# 1755  2021        24  Centre-Val de Loire        28  Eure-et-Loir
# 1756  2021        24  Centre-Val de Loire        28  Eure-et-Loir
#
#       arrdep_code           arrdep_name  ze2020_code  ze2020_name  \
# 0             182  Saint-Amand-Montrond         2402      Bourges
# ...

# %%
print(pd.io.sql.get_schema(gdf, name="georef_data", con=engine))
# Out:
# CREATE TABLE georef_data (
# 	year BIGINT,
# 	reg_code BIGINT,
# 	reg_name TEXT,
# 	dep_code BIGINT,
# 	dep_name TEXT,
# 	arrdep_code BIGINT,
# 	arrdep_name TEXT,
# 	ze2020_code BIGINT,
# 	ze2020_name TEXT,
# 	bv2012_code BIGINT,
# 	bv2012_name TEXT,
# 	epci_code BIGINT,
# 	epci_name TEXT,
# 	com_code BIGINT,
# 	com_current BIGINT,
# 	com_name TEXT,
# 	com_name_up TEXT,
# 	com_name_lo TEXT,
# 	com_area_co TEXT,
# 	com_type TEXT,
# 	com_cateaav TEXT,
# 	com_uu2020_ TEXT,
# 	com_aav2020 BIGINT,
# 	com_cv_code BIGINT,
# 	com_in_ctu TEXT,
# 	com_siren_c BIGINT,
# 	com_is_moun TEXT,
# 	geometry TEXT
# )

# %%
gdf.columns
# Out:
# Index(['year', 'reg_code', 'reg_name', 'dep_code', 'dep_name', 'arrdep_code',
#        'arrdep_name', 'ze2020_code', 'ze2020_name', 'bv2012_code',
#        'bv2012_name', 'epci_code', 'epci_name', 'com_code', 'com_current',
#        'com_name', 'com_name_up', 'com_name_lo', 'com_area_co', 'com_type',
#        'com_cateaav', 'com_uu2020_', 'com_aav2020', 'com_cv_code',
#        'com_in_ctu', 'com_siren_c', 'com_is_moun', 'geometry'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['code_insee', 'val_ind', 'conc_pm10', 'conc_pm25', 'conc_no2',
#        'conc_so2', 'conc_o3', 'poll_resp', 'date_run', 'date_ech'],
#       dtype='object')

# %%
gdf.to_sql(con=con, name="geo_ref", if_exists="replace")
# Out:
# 757

# %% [markdown]
# # Connexion to Sqlite database

# %%
# Connexion à la base de données
conn = sqlite3.connect('pollution.sqlite')
# Création d'un curseur
cur = conn.cursor()
# Exécution d'une requête
cur.execute("SELECT * FROM pollution_data")

# Récupération des résultats
results = pd.DataFrame(cur.fetchall(),columns=['code_insee', 'val_ind', 'conc_pm10', 'conc_pm25', 'conc_no2',
       'conc_so2', 'conc_o3', 'poll_resp', 'date_run', 'date_ech'])
#results = pd.DataFrame(cur.fetchall())    
                                               
results.head()
# Fermeture de la connexion
#conn.close()

# Affichage des résultats
#for row in results:
    #print(row)
# Out:
#    code_insee  val_ind  conc_pm10  conc_pm25  conc_no2  conc_so2  conc_o3  \
# 0       28415        4       22.7       11.6      23.8       0.4    155.7
# 1       37094        4       16.2        9.4      16.1       0.1    145.1
# 2       18273        4       12.6        7.5      12.9       0.2    137.6
# 3       41217        4       14.5        8.3      16.7       0.1    149.0
# 4       28182        4       20.4       10.4      21.9       0.2    152.3
#
#   poll_resp                    date_run                    date_ech
# 0        o3  2023-06-14 00:00:00.000000  2023-06-16 00:00:00.000000
# 1        o3  2023-06-14 00:00:00.000000  2023-06-16 00:00:00.000000
# 2        o3  2023-06-14 00:00:00.000000  2023-06-16 00:00:00.000000
# 3        o3  2023-06-14 00:00:00.000000  2023-06-16 00:00:00.000000
# 4        o3  2023-06-14 00:00:00.000000  2023-06-16 00:00:00.000000

# %%
results
# Out:
#        code_insee  val_ind  conc_pm10  conc_pm25  conc_no2  conc_so2  conc_o3  \
# 0           28415        4       22.7       11.6      23.8       0.4    155.7
# 1           37094        4       16.2        9.4      16.1       0.1    145.1
# 2           18273        4       12.6        7.5      12.9       0.2    137.6
# 3           41217        4       14.5        8.3      16.7       0.1    149.0
# 4           28182        4       20.4       10.4      21.9       0.2    152.3
# ...           ...      ...        ...        ...       ...       ...      ...
# 15808       28296        4       19.1        9.7      19.8       0.2    150.2
# 15809       41286        4       16.4        8.8      19.1       0.1    150.8
# 15810       37169        4       16.1        8.8      19.3       0.1    149.8
# 15811       18226        4       14.8        8.0      16.1       0.2    135.9
# 15812       18179        4       14.4        7.7      15.1       0.1    136.8
#
# ...

# %%
# Récupération des résultats
results = pd.DataFrame(cur.fetchall(),columns=['year', 'reg_code', 'reg_name', 'dep_code', 'dep_name', 'arrdep_code',
       'arrdep_name', 'ze2020_code', 'ze2020_name', 'bv2012_code',
       'bv2012_name', 'epci_code', 'epci_name', 'com_code', 'com_current',
       'com_name', 'com_name_up', 'com_name_lo', 'com_area_co', 'com_type',
       'com_cateaav', 'com_uu2020_', 'com_aav2020', 'com_cv_code',
       'com_in_ctu', 'com_siren_c', 'com_is_moun', 'geometry'])
#results = pd.DataFrame(cur.fetchall())    
results.head()

# %%
# Connexion à la base de données
conn = sqlite3.connect('georef.sqlite')
# Création d'un curseur
cur = conn.cursor()
# Exécution d'une requête
cur.execute("SELECT * FROM georef_data")

# Récupération des résultats
results = pd.DataFrame(cur.fetchall(),columns=['year', 'reg_code', 'reg_name', 'dep_code', 'dep_name', 'arrdep_code',
       'arrdep_name', 'ze2020_code', 'ze2020_name', 'bv2012_code',
       'bv2012_name', 'epci_code', 'epci_name', 'com_code', 'com_current',
       'com_name', 'com_name_up', 'com_name_lo', 'com_area_co', 'com_type',
       'com_cateaav', 'com_uu2020_', 'com_aav2020', 'com_cv_code',
       'com_in_ctu', 'com_siren_c', 'com_is_moun', 'geometry'])
#results = pd.DataFrame(cur.fetchall())    
results.head()
# Fermeture de la connexion
# instead of cursor.description:
#row = cur.fetchone()
#conn.close()
# Out:
#    year  reg_code             reg_name  dep_code dep_name  arrdep_code  \
# 0  2021        24  Centre-Val de Loire        18     Cher          182
# 1  2021        24  Centre-Val de Loire        18     Cher          182
# 2  2021        24  Centre-Val de Loire        18     Cher          181
# 3  2021        24  Centre-Val de Loire        18     Cher          182
# 4  2021        24  Centre-Val de Loire        18     Cher          181
#
#             arrdep_name  ze2020_code ze2020_name  bv2012_code  ...  \
# 0  Saint-Amand-Montrond         2402     Bourges        18197  ...
# 1  Saint-Amand-Montrond         2402     Bourges        18197  ...
# 2               Bourges         2402     Bourges        58059  ...
# 3  Saint-Amand-Montrond           60      Nevers        18242  ...
# 4               Bourges         2402     Bourges        18087  ...
#
#   com_area_co  com_type                         com_cateaav  \
# 0         FXX   commune              Commune de la couronne
# ...

# %%
results.isnull().sum()
# Out:
# year           0
# reg_code       0
# reg_name       0
# dep_code       0
# dep_name       0
# arrdep_code    0
# arrdep_name    0
# ze2020_code    0
# ze2020_name    0
# bv2012_code    0
# bv2012_name    0
# epci_code      0
# epci_name      0
# com_code       0
# com_current    0
# com_name       0
# com_name_up    0
# com_name_lo    0
# com_area_co    0
# com_type       0
# com_cateaav    0
# com_uu2020_    0
# com_aav2020    0
# com_cv_code    0
# com_in_ctu     0
# com_siren_c    0
# com_is_moun    0
# geometry       0
# dtype: int64
